# %% [markdown]
# # Instalación de qiskit

# %%
# !pip install qiskit
# !pip -q install -U qiskit qiskit-aer
# !pip install qiskit[visualization]
# !pip -q install -U qiskit[visualization] qiskit-aer
# Out:
# Requirement already satisfied: qiskit in c:\users\usuario\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\usuario\anaconda3\lib\site-packages (from qiskit) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in c:\users\usuario\anaconda3\lib\site-packages (from qiskit) (2.1.3)
# Requirement already satisfied: scipy>=1.5 in c:\users\usuario\anaconda3\lib\site-packages (from qiskit) (1.15.3)
# Requirement already satisfied: dill>=0.3 in c:\users\usuario\anaconda3\lib\site-packages (from qiskit) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\usuario\anaconda3\lib\site-packages (from qiskit) (5.5.0)
# Requirement already satisfied: typing-extensions in c:\users\usuario\anaconda3\lib\site-packages (from qiskit) (4.12.2)
# Requirement already satisfied: qiskit[visualization] in c:\users\usuario\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\usuario\anaconda3\lib\site-packages (from qiskit[visualization]) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in c:\users\usuario\anaconda3\lib\site-packages (from qiskit[visualization]) (2.1.3)
# Requirement already satisfied: scipy>=1.5 in c:\users\usuario\anaconda3\lib\site-packages (from qiskit[visualization]) (1.15.3)
# Requirement already satisfied: dill>=0.3 in c:\users\usuario\anaconda3\lib\site-packages (from qiskit[visualization]) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\usuario\anaconda3\lib\site-packages (from qiskit[visualization]) (5.5.0)
# Requirement already satisfied: typing-extensions in c:\users\usuario\anaconda3\lib\site-packages (from qiskit[visualization]) (4.12.2)
# Requirement already satisfied: matplotlib>=3.3 in c:\users\usuario\anaconda3\lib\site-packages (from qiskit[visualization]) (3.10.0)
# Requirement already satisfied: pydot in c:\users\usuario\anaconda3\lib\site-packages (from qiskit[visualization]) (4.0.1)
# Requirement already satisfied: Pillow>=4.2.1 in c:\users\usuario\anaconda3\lib\site-packages (from qiskit[visualization]) (11.1.0)
# Requirement already satisfied: pylatexenc>=1.4 in c:\users\usuario\anaconda3\lib\site-packages (from qiskit[visualization]) (2.10)
# Requirement already satisfied: seaborn>=0.9.0 in c:\users\usuario\anaconda3\lib\site-packages (from qiskit[visualization]) (0.13.2)
# Requirement already satisfied: sympy>=1.3 in c:\users\usuario\anaconda3\lib\site-packages (from qiskit[visualization]) (1.13.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib>=3.3->qiskit[visualization]) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\usuario\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3->qiskit[visualization]) (1.17.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\usuario\anaconda3\lib\site-packages (from seaborn>=0.9.0->qiskit[visualization]) (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\usuario\anaconda3\lib\site-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit[visualization]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\usuario\anaconda3\lib\site-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit[visualization]) (2025.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\usuario\anaconda3\lib\site-packages (from sympy>=1.3->qiskit[visualization]) (1.3.0)

# %% [markdown]
# Se definen las librerias necesarias y se comprueba la version de qiskit utilizada

# %%
from qiskit import QuantumCircuit, transpile
from qiskit.visualization import plot_histogram
from qiskit.circuit.library import grover_operator
from qiskit_aer import AerSimulator
from qiskit_aer.noise import (NoiseModel, QuantumError, ReadoutError,
    pauli_error, depolarizing_error, thermal_relaxation_error)
import time

# %% [markdown]
# Se define la funcion oraculo (en este caso Grover) y se construye el circuito grover simulando el circuito necesario para su implementación

# %%
oracle = QuantumCircuit(2)
oracle.cz(0, 1)

grover_op = grover_operator(oracle)

qc = QuantumCircuit(2, 2)
qc.h([0, 1])
qc.compose(grover_op, inplace=True)
qc.measure([0, 1], [0, 1])

# %% [markdown]
# Ahora se simula un circuito ideal, en otras palabras un circuito sin ruido para mostrar un escenario donde el circuito entrega en todas las ocasiones el resultado esperado

# %%
# 4. Simulate the Circuit
simulator = AerSimulator()
compiled_circuit = transpile(qc, simulator)
start = time.time()        
job = simulator.run(compiled_circuit, shots=1024)
result = job.result()
end = time.time()          

print("Tiempo de ejecución:", end - start, "segundos")

counts = result.get_counts(qc)

# 5. Visualize the results
print("Measurement counts:", counts)
plot_histogram(counts)
# Out:
# Tiempo de ejecución: 0.003795146942138672 segundos
# Measurement counts: {'11': 1024}

# %% [markdown]
# # Version Con Ruido
# Esta versión del codigo inplementa un modelo de ruido simulando el NISQ donde los qubits presentan errores en las compuertas logicas simulando el estado actual de la computación cuantica

# %%
noise_model = NoiseModel()

error_1q = depolarizing_error(0.02, 1)  # 2% de error
error_2q = depolarizing_error(0.05, 2)  # 5% de error

noise_model.add_all_qubit_quantum_error(error_1q, ['h'])
noise_model.add_all_qubit_quantum_error(error_2q, ['cx', 'cz'])
start = time.time()        
simulator = AerSimulator(noise_model=noise_model)
compiled_circuit = transpile(qc, simulator)
job = simulator.run(compiled_circuit, shots=1024)
end = time.time()        
result = job.result()
counts = result.get_counts(qc)
print("Tiempo de ejecución:", end - start, "segundos")

print("Measurement counts with noise:", counts)
plot_histogram(counts)
# Out:
# Tiempo de ejecución: 0.05106377601623535 segundos
# Measurement counts with noise: {'11': 947, '00': 25, '01': 28, '10': 24}

# %% [markdown]
# Ahora calculamos la fidelidad del circuito mediante el calculo de resultado esperados partido por shors totales

# %%
# Supongamos que el resultado esperado es '11'
expected_result = '11'

# Número de veces que obtuvimos el resultado esperado
hits = counts.get(expected_result, 0)
shots=1024

fidelity = hits / shots
print(f"Fidelidad del resultado esperado '{expected_result}': {fidelity:.4f}")
# Out:
# Fidelidad del resultado esperado '11': 0.9248
