# %%
# !pip install cirq
# Out:
# Requirement already satisfied: cirq in c:\users\usuario\anaconda3\lib\site-packages (1.6.1)
# Requirement already satisfied: cirq-aqt==1.6.1 in c:\users\usuario\anaconda3\lib\site-packages (from cirq) (1.6.1)
# Requirement already satisfied: cirq-core==1.6.1 in c:\users\usuario\anaconda3\lib\site-packages (from cirq) (1.6.1)
# Requirement already satisfied: cirq-google==1.6.1 in c:\users\usuario\anaconda3\lib\site-packages (from cirq) (1.6.1)
# Requirement already satisfied: cirq-ionq==1.6.1 in c:\users\usuario\anaconda3\lib\site-packages (from cirq) (1.6.1)
# Requirement already satisfied: cirq-pasqal==1.6.1 in c:\users\usuario\anaconda3\lib\site-packages (from cirq) (1.6.1)
# Requirement already satisfied: cirq-web==1.6.1 in c:\users\usuario\anaconda3\lib\site-packages (from cirq) (1.6.1)
# Requirement already satisfied: requests~=2.32 in c:\users\usuario\anaconda3\lib\site-packages (from cirq-aqt==1.6.1->cirq) (2.32.5)
# Requirement already satisfied: attrs>=21.3.0 in c:\users\usuario\anaconda3\lib\site-packages (from cirq-core==1.6.1->cirq) (24.3.0)
# Requirement already satisfied: duet>=0.2.8 in c:\users\usuario\anaconda3\lib\site-packages (from cirq-core==1.6.1->cirq) (0.2.9)
# Requirement already satisfied: matplotlib~=3.8 in c:\users\usuario\anaconda3\lib\site-packages (from cirq-core==1.6.1->cirq) (3.10.0)
# Requirement already satisfied: networkx~=3.4 in c:\users\usuario\anaconda3\lib\site-packages (from cirq-core==1.6.1->cirq) (3.4.2)
# Requirement already satisfied: numpy>=1.26 in c:\users\usuario\anaconda3\lib\site-packages (from cirq-core==1.6.1->cirq) (2.1.3)
# Requirement already satisfied: pandas~=2.1 in c:\users\usuario\anaconda3\lib\site-packages (from cirq-core==1.6.1->cirq) (2.2.3)
# Requirement already satisfied: sortedcontainers~=2.0 in c:\users\usuario\anaconda3\lib\site-packages (from cirq-core==1.6.1->cirq) (2.4.0)
# Requirement already satisfied: scipy~=1.12 in c:\users\usuario\anaconda3\lib\site-packages (from cirq-core==1.6.1->cirq) (1.15.3)
# Requirement already satisfied: sympy in c:\users\usuario\anaconda3\lib\site-packages (from cirq-core==1.6.1->cirq) (1.13.3)
# Requirement already satisfied: typing_extensions>=4.2 in c:\users\usuario\anaconda3\lib\site-packages (from cirq-core==1.6.1->cirq) (4.12.2)
# Requirement already satisfied: tqdm>=4.12 in c:\users\usuario\anaconda3\lib\site-packages (from cirq-core==1.6.1->cirq) (4.67.1)
# Requirement already satisfied: google-api-core~=2.22 in c:\users\usuario\anaconda3\lib\site-packages (from google-api-core[grpc]~=2.22->cirq-google==1.6.1->cirq) (2.28.1)
# Requirement already satisfied: proto-plus~=1.25 in c:\users\usuario\anaconda3\lib\site-packages (from cirq-google==1.6.1->cirq) (1.26.1)
# Requirement already satisfied: protobuf<6.0dev,>=5.26.1 in c:\users\usuario\anaconda3\lib\site-packages (from cirq-google==1.6.1->cirq) (5.29.3)
# Requirement already satisfied: typedunits in c:\users\usuario\anaconda3\lib\site-packages (from cirq-google==1.6.1->cirq) (0.0.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\usuario\anaconda3\lib\site-packages (from google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq-google==1.6.1->cirq) (1.71.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\users\usuario\anaconda3\lib\site-packages (from google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq-google==1.6.1->cirq) (2.42.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\usuario\anaconda3\lib\site-packages (from google-api-core[grpc]~=2.22->cirq-google==1.6.1->cirq) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\usuario\anaconda3\lib\site-packages (from google-api-core[grpc]~=2.22->cirq-google==1.6.1->cirq) (1.71.2)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\usuario\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq-google==1.6.1->cirq) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\usuario\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq-google==1.6.1->cirq) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\usuario\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq-google==1.6.1->cirq) (4.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib~=3.8->cirq-core==1.6.1->cirq) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\usuario\anaconda3\lib\site-packages (from pandas~=2.1->cirq-core==1.6.1->cirq) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\usuario\anaconda3\lib\site-packages (from pandas~=2.1->cirq-core==1.6.1->cirq) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\usuario\anaconda3\lib\site-packages (from requests~=2.32->cirq-aqt==1.6.1->cirq) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\usuario\anaconda3\lib\site-packages (from requests~=2.32->cirq-aqt==1.6.1->cirq) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\usuario\anaconda3\lib\site-packages (from requests~=2.32->cirq-aqt==1.6.1->cirq) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\usuario\anaconda3\lib\site-packages (from requests~=2.32->cirq-aqt==1.6.1->cirq) (2025.11.12)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\usuario\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-api-core~=2.22->google-api-core[grpc]~=2.22->cirq-google==1.6.1->cirq) (0.4.8)
# Requirement already satisfied: six>=1.5 in c:\users\usuario\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib~=3.8->cirq-core==1.6.1->cirq) (1.17.0)
# Requirement already satisfied: colorama in c:\users\usuario\anaconda3\lib\site-packages (from tqdm>=4.12->cirq-core==1.6.1->cirq) (0.4.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\usuario\anaconda3\lib\site-packages (from sympy->cirq-core==1.6.1->cirq) (1.3.0)
# Requirement already satisfied: cython>=3.0.0 in c:\users\usuario\anaconda3\lib\site-packages (from typedunits->cirq-google==1.6.1->cirq) (3.1.6)

# %%
import cirq
import cirq_google
import matplotlib.pyplot as plt
import time

# %%
q0, q1 = cirq.LineQubit.range(2)
ancilla = cirq.NamedQubit("Ancilla")

def make_oracle(qubits, ancilla):
    return cirq.TOFFOLI(qubits[0], qubits[1], ancilla)

# Función para una iteración de Grover
def grover_iteration(qubits, ancilla, oracle):
    circuit = cirq.Circuit()

    # 1. Superposición inicial
    circuit.append(cirq.H.on_each(*qubits))

    # 2. Preparar ancilla en |->
    circuit.append([cirq.X(ancilla), cirq.H(ancilla)])

    # 3. Aplicar oracle
    circuit.append(oracle)

    # 4. Difusor (inversión sobre la media)
    circuit.append(cirq.H.on_each(*qubits))
    circuit.append(cirq.X.on_each(*qubits))
    circuit.append(cirq.H(qubits[1]))
    circuit.append(cirq.CNOT(qubits[0], qubits[1]))
    circuit.append(cirq.H(qubits[1]))
    circuit.append(cirq.X.on_each(*qubits))
    circuit.append(cirq.H.on_each(*qubits))

    # 5. Medición
    circuit.append(cirq.measure(*qubits, key='result'))

    return circuit

# %%
# Crear el oracle
oracle = make_oracle([q0, q1], ancilla)
circuit = grover_iteration([q0, q1], ancilla, oracle)
# Simulación
start = time.time()
simulator = cirq.Simulator()
result = simulator.run(circuit, repetitions=1024)
end = time.time()

# Contar resultados
counts = result.histogram(key='result')
labels = [f"{b:02b}" for b in counts.keys()]

# Dibujar histograma
plt.bar(labels, counts.values(), color="#70CEFF")
plt.xlabel("Estado medido")
plt.ylabel("Frecuencia")
plt.title("Grover en Cirq (2 qubits, solución = |11>)")
plt.show()

# Mostrar resultados
print("Tiempo de ejecución en el simulador:", end - start, "segundos")
print("Resultados de la medición:", dict(zip(labels, counts.values())))
# Out:
# Tiempo de ejecución en el simulador: 0.011977195739746094 segundos
# Resultados de la medición: {'11': 1024}

# %%
# --- Qubits: usar los qubits del procesador virtual ---
# Tomamos los primeros 3 qubits que figuran en noise_props
processor_id = "willow_pink"
noise_props = cirq_google.engine.load_device_noise_properties(processor_id)
qubits_list = list(noise_props.qubits)[:3]  # necesitamos 2 input + 1 ancilla
q0, q1, ancilla = qubits_list

# --- Oracle para |11> usando Toffoli ---
def make_oracle(qubits, ancilla):
    return cirq.TOFFOLI(qubits[0], qubits[1], ancilla)

# --- Construir circuito ---
oracle = make_oracle([q0, q1], ancilla)
circuit = grover_iteration([q0, q1], ancilla, oracle)

# --- Crear NoiseModel desde las propiedades del procesador ---
noise_model = cirq_google.NoiseModelFromGoogleNoiseProperties(noise_props)

# --- Simulación con ruido realista ---
start = time.time()
simulator = cirq.DensityMatrixSimulator(noise=noise_model)
result = simulator.run(circuit, repetitions=1024)
end = time.time()


# --- Contar resultados ---
counts = result.histogram(key='result')
labels = [f"{b:02b}" for b in counts.keys()]

# --- Dibujar histograma ---
plt.bar(labels, counts.values(), color="#FF7070")
plt.xlabel("Estado medido")
plt.ylabel("Frecuencia")
plt.title(f"Grover NISQ (2 qubits, solución = |11>, {processor_id})")
plt.show()

# --- Resultados ---
print("Tiempo de ejecución en el simulador:", end - start, "segundos")
print("Resultados de la medición con ruido realista:", dict(zip(labels, counts.values())))
# Out:
# Tiempo de ejecución en el simulador: 0.044162750244140625 segundos
# Resultados de la medición con ruido realista: {'11': 1002, '00': 1, '10': 10, '01': 11}

# %%
results_dict = dict(zip(labels, counts.values()))
expected_result = "11"  # estado objetivo de Grover
shots = sum(counts.values())
hits = results_dict.get(expected_result, 0)
fidelity = hits / shots

print(f"Fidelidad clásica respecto al estado objetivo '{expected_result}': {fidelity:.4f}")
# Out:
# Fidelidad clásica respecto al estado objetivo '11': 0.9785
