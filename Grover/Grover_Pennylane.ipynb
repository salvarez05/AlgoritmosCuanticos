# %%
# !pip install pennylane
# Out:
# Requirement already satisfied: pennylane in c:\users\usuario\anaconda3\lib\site-packages (0.43.0)
# Requirement already satisfied: scipy in c:\users\usuario\anaconda3\lib\site-packages (from pennylane) (1.15.3)
# Requirement already satisfied: networkx in c:\users\usuario\anaconda3\lib\site-packages (from pennylane) (3.4.2)
# Requirement already satisfied: rustworkx>=0.14.0 in c:\users\usuario\anaconda3\lib\site-packages (from pennylane) (0.17.1)
# Requirement already satisfied: autograd in c:\users\usuario\anaconda3\lib\site-packages (from pennylane) (1.8.0)
# Requirement already satisfied: appdirs in c:\users\usuario\anaconda3\lib\site-packages (from pennylane) (1.4.4)
# Requirement already satisfied: autoray==0.8.0 in c:\users\usuario\anaconda3\lib\site-packages (from pennylane) (0.8.0)
# Requirement already satisfied: cachetools in c:\users\usuario\anaconda3\lib\site-packages (from pennylane) (5.5.1)
# Requirement already satisfied: pennylane-lightning>=0.43 in c:\users\usuario\anaconda3\lib\site-packages (from pennylane) (0.43.0)
# Requirement already satisfied: requests in c:\users\usuario\anaconda3\lib\site-packages (from pennylane) (2.32.5)
# Requirement already satisfied: tomlkit in c:\users\usuario\anaconda3\lib\site-packages (from pennylane) (0.13.2)
# Requirement already satisfied: typing_extensions in c:\users\usuario\anaconda3\lib\site-packages (from pennylane) (4.12.2)
# Requirement already satisfied: packaging in c:\users\usuario\anaconda3\lib\site-packages (from pennylane) (24.2)
# Requirement already satisfied: diastatic-malt in c:\users\usuario\anaconda3\lib\site-packages (from pennylane) (2.15.2)
# Requirement already satisfied: numpy in c:\users\usuario\anaconda3\lib\site-packages (from pennylane) (2.1.3)
# Requirement already satisfied: scipy-openblas32>=0.3.26 in c:\users\usuario\anaconda3\lib\site-packages (from pennylane-lightning>=0.43->pennylane) (0.3.30.0.6)
# Requirement already satisfied: astunparse in c:\users\usuario\anaconda3\lib\site-packages (from diastatic-malt->pennylane) (1.6.3)
# Requirement already satisfied: gast in c:\users\usuario\anaconda3\lib\site-packages (from diastatic-malt->pennylane) (0.6.0)
# Requirement already satisfied: termcolor in c:\users\usuario\anaconda3\lib\site-packages (from diastatic-malt->pennylane) (3.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\usuario\anaconda3\lib\site-packages (from astunparse->diastatic-malt->pennylane) (0.45.1)
# Requirement already satisfied: six<2.0,>=1.6.1 in c:\users\usuario\anaconda3\lib\site-packages (from astunparse->diastatic-malt->pennylane) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\usuario\anaconda3\lib\site-packages (from requests->pennylane) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\usuario\anaconda3\lib\site-packages (from requests->pennylane) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\usuario\anaconda3\lib\site-packages (from requests->pennylane) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\usuario\anaconda3\lib\site-packages (from requests->pennylane) (2025.11.12)

# %% [markdown]
# Librerias necesarias

# %%
import pennylane as qml
from pennylane import numpy as np
import matplotlib.pyplot as plt
import time

# %%
NUM_QUBITS = 2
wires = list(range(NUM_QUBITS))

dev = qml.device("default.mixed", wires=NUM_QUBITS, shots=1024)
# Out:
# C:\Users\Usuario\anaconda3\Lib\site-packages\pennylane\devices\device_api.py:193: PennyLaneDeprecationWarning: Setting shots on device is deprecated. Please use the `set_shots` transform on the respective QNode instead.
#   warnings.warn(

# %%
def equal_superposition(wires):
    for wire in wires:
        qml.Hadamard(wires=wire)

def oracle(wires, omega):
    for w, bit in enumerate(omega):
        if bit == 0:
            qml.PauliX(wires=w)
    qml.ctrl(qml.PauliZ, control=wires[0])(wires[1])
    for w, bit in enumerate(omega):
        if bit == 0:
            qml.PauliX(wires=w)

def diffusion_operator(wires):
    for wire in wires:
        qml.Hadamard(wires=wire)
        qml.PauliX(wires=wire)
    qml.ctrl(qml.PauliZ, control=wires[0])(wires[1])
    for wire in wires:
        qml.PauliX(wires=wire)
        qml.Hadamard(wires=wire)

# %%
# --- Canal de ruido ---
def add_noise():
    """Aplica un poco de depolarización a cada qubit para simular NISQ."""
    for wire in wires:
        qml.DepolarizingChannel(0.02, wires=wire)  # 2% de ruido por qubit

# --- Circuito principal ---
@qml.qnode(dev)
def grover_noisy():
    equal_superposition(wires)
    omega = np.array([0, 0])
    oracle(wires, omega)
    diffusion_operator(wires)
    add_noise()  # agregamos ruido al final
    return qml.sample(wires=wires)

# %%
# --- Ejecución ---
start = time.time()
samples = grover_noisy()
end = time.time()

# Contamos los resultados
counts = {}
for s in samples:
    key = "".join(str(int(x)) for x in s)
    counts[key] = counts.get(key, 0) + 1

# --- Visualización ---
plt.bar(counts.keys(), counts.values(), color="#70CEFF")
plt.xlabel("Estado medido")
plt.ylabel("Frecuencia (de 1024 shots)")
plt.title("Grover con ruido simulado (2 qubits, objetivo = |00⟩)")
plt.show()

print("Tiempo de ejecución en el simulador:", end - start, "segundos")
print("Resultados con ruido:", counts)
# Out:
# Tiempo de ejecución en el simulador: 0.016845226287841797 segundos
# Resultados con ruido: {'01': 17, '00': 989, '10': 18}

# %%
expected_result = "00"
hits = counts.get(expected_result, 0)
shots=1024
fidelity = hits / shots

print(f"Fidelidad clásica respecto al estado objetivo '{expected_result}': {fidelity:.4f}")
# Out:
# Fidelidad clásica respecto al estado objetivo '00': 0.9658

# %%
print(qml.__version__)
# Out:
# 0.43.0
